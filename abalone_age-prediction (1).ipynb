# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("abalone.csv")

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
sns.barplot(x='Sex',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
sns.barplot(x='Length',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(x='Diameter',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
plt.scatter(data['Height'],data['Rings'],color='blue')

# %%
sns.barplot(x='Whole weight',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
plt.scatter(data['Shucked weight'],data['Rings'],color='blue')

# %%
sns.scatterplot(x='Viscera weight',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Rings'>

# %%
sns.boxplot(x='Shell weight',y='Rings',data=data)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
data['Sex']
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Sex, Length: 4177, dtype: object

# %%
data['Sex']=le.fit_transform(data['Sex'])

# %%
data
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
sns.boxplot(x='Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
sns.boxplot(x='Length',data=data)
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(x='Diameter',data=data)
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(x='Height',data=data)
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(x='Whole weight',data=data)
# Out:
# <AxesSubplot:xlabel='Whole weight'>

# %%
sns.boxplot(x='Shucked weight',data=data)
# Out:
# <AxesSubplot:xlabel='Shucked weight'>

# %%
sns.boxplot(x='Viscera weight',data=data)
# Out:
# <AxesSubplot:xlabel='Viscera weight'>

# %%
sns.boxplot(x='Shell weight',data=data)
# Out:
# <AxesSubplot:xlabel='Shell weight'>

# %%
from scipy import stats
z=np.abs(stats.zscore(data))

# %%
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
z[55][1]
# Out:
# 0.19980339826798219

# %%
cleaned_data = data[(z<3).all(axis=1)]

# %%
cleaned_data.shape
# Out:
# (4027, 9)

# %%
data.shape
# Out:
# (4177, 9)

# %%
q1 = data.quantile(0.25) #25%

# %%
q3 = data.quantile(0.75) #75%

# %%
IQR = q3-q1 #50%

# %%
a = q1-1.3*IQR

# %%
b = q3+1.3*IQR

# %%
b
# Out:
# Sex                4.60000
# Length             0.82950
# Diameter           0.64900
# Height             0.23000
# Whole weight       2.07795
# Shucked weight     0.91280
# Viscera weight     0.46035
# Shell weight       0.58770
# Rings             14.90000
# dtype: float64

# %%
(data<(q1-1.3*IQR))|(data>(q3+1.3*IQR))
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False            True
#
#       Viscera weight  Shell weight  Rings
# 0              False         False   True
# 1              False         False  False
# ...

# %%
iqr_clean=data[~((data<(q1-1.3*IQR))|(data>(q3+1.3*IQR))).any(axis=1)]

# %%
iqr_clean.shape
# Out:
# (3590, 9)

# %%
data.shape
# Out:
# (4177, 9)

# %%
iqr_clean
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# 5       1   0.425     0.300   0.095        0.3515          0.1410
# ...   ...     ...       ...     ...           ...             ...
# 4171    2   0.560     0.430   0.155        0.8675          0.4000
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
#
#       Viscera weight  Shell weight  Rings
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# ...

# %%
sns.boxplot(x=iqr_clean['Length'])
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(x=iqr_clean['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(x=iqr_clean['Height'])
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(x=iqr_clean['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight'>

# %%
sns.boxplot(x=iqr_clean['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Shucked weight'>

# %%
sns.boxplot(x=iqr_clean['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight'>

# %%
sns.boxplot(x=iqr_clean['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight'>

# %%
x=data.iloc[:,0:8]

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
#
#                 Shucked weight  Viscera weight  Shell weight
# Sex                  -0.001373       -0.032067     -0.034854
# Length                0.897914        0.903018      0.897706
# Diameter              0.893162        0.899724      0.905330
# Height                0.774972        0.798319      0.817338
# ...

# %%
x=x.values

# %%
x
# Out:
# array([[2.    , 0.455 , 0.365 , ..., 0.2245, 0.101 , 0.15  ],
#        [2.    , 0.35  , 0.265 , ..., 0.0995, 0.0485, 0.07  ],
#        [0.    , 0.53  , 0.42  , ..., 0.2565, 0.1415, 0.21  ],
#        ...,
#        [2.    , 0.6   , 0.475 , ..., 0.5255, 0.2875, 0.308 ],
#        [0.    , 0.625 , 0.485 , ..., 0.531 , 0.261 , 0.296 ],
#        [2.    , 0.71  , 0.555 , ..., 0.9455, 0.3765, 0.495 ]])

# %%
y=data.iloc[:,8:]

# %%
y
# Out:
#       Rings
# 0        15
# 1         7
# 2         9
# 3        10
# 4         7
# ...     ...
# 4172     11
# 4173     10
# 4174      9
# 4175     10
# 4176     12
#
# [4177 rows x 1 columns]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
y=y.values

# %%
y
# Out:
# array([[15],
#        [ 7],
#        [ 9],
#        ...,
#        [ 9],
#        [10],
#        [12]], dtype=int64)

# %%
#from sklearn.preprocessing import OneHotEncoder
#one=OneHotEncoder()

# %%
#z=one.fit_transform(x[:,0:1]).toarray()

# %%
#z

# %%
#x=np.delete(x,0,axis=1)

# %%
#x=np.concatenate((z,x),axis=1)

# %%
#x.shape

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.15198011, -0.57455813, -0.43214879, ..., -0.60768536,
#         -0.72621157, -0.63821689],
#        [ 1.15198011, -1.44898585, -1.439929  , ..., -1.17090984,
#         -1.20522124, -1.21298732],
#        [-1.28068972,  0.05003309,  0.12213032, ..., -0.4634999 ,
#         -0.35668983, -0.20713907],
#        ...,
#        [ 1.15198011,  0.6329849 ,  0.67640943, ...,  0.74855917,
#          0.97541324,  0.49695471],
#        [-1.28068972,  0.84118198,  0.77718745, ...,  0.77334105,
#          0.73362741,  0.41073914],
#        [ 1.15198011,  1.54905203,  1.48263359, ...,  2.64099341,
#          1.78744868,  1.84048058]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[-0.0643548 , -2.86472596, -2.75004326, ..., -1.55390248,
#         -1.58386698, -1.64406514],
#        [-0.0643548 , -2.57325005, -2.59887623, ..., -1.55164959,
#         -1.56561899, -1.62610356],
#        [ 1.15198011,  1.13265788,  1.23068854, ...,  1.0414359 ,
#          0.28655172,  1.53872611],
#        ...,
#        [ 1.15198011,  0.59134549,  0.42446438, ...,  0.46694694,
#          0.23636976,  0.10539235],
#        [-1.28068972,  0.84118198,  0.82757646, ...,  0.53002808,
#          0.51008957,  0.57239333],
#        [-0.0643548 , -0.94931287, -0.83526087, ..., -1.02221858,
#         -0.96343541, -0.99026378]])

# %%
x_train.shape,x_test.shape
# Out:
# ((3341, 8), (836, 8))

# %%
y_train.shape,y_test.shape
# Out:
# ((3341, 1), (836, 1))

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
y_test
# Out:
# array([[13],
#        [ 8],
#        [11],
#        [ 5],
#        [12],
#        [11],
#        [ 7],
#        [ 8],
#        [ 7],
#        [ 9],
#        [ 8],
#        [ 8],
#        [11],
#        [ 9],
#        [ 4],
#        [ 7],
#        [ 7],
#        [17],
#        [ 7],
#        [ 7],
#        [ 7],
#        [ 5],
#        [ 8],
#        [ 9],
#        [10],
#        [10],
#        [ 5],
#        [15],
#        [10],
#        [14],
#        [ 8],
#        [ 4],
#        [ 9],
#        [13],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 9],
#        [ 8],
#        [11],
#        [15],
#        [12],
#        [17],
#        [16],
#        [11],
#        [11],
#        [ 8],
#        [10],
#        [11],
#        [ 6],
#        [13],
#        [ 7],
#        [13],
#        [20],
#        [12],
#        [ 7],
#        [ 8],
#        [10],
#        [ 7],
#        [ 7],
#        [ 9],
#        [ 9],
#        [11],
#        [ 8],
#        [ 7],
#        [12],
# ...

# %%
y_pred_lr=lr.predict(x_test)
y_pred_lr
# Out:
# array([[13.0578998 ],
#        [ 9.65069759],
#        [10.38007246],
#        [ 5.64401046],
#        [10.70865673],
#        [11.95000656],
#        [ 7.83730768],
#        [ 9.82182786],
#        [ 8.42144478],
#        [12.27630026],
#        [ 8.69875967],
#        [ 6.43514928],
#        [ 7.98532548],
#        [ 9.00409661],
#        [ 5.80540646],
#        [ 9.22631732],
#        [ 7.75674819],
#        [13.89379232],
#        [10.99393621],
#        [ 8.191136  ],
#        [ 7.74226919],
#        [ 7.16197224],
#        [ 9.34707873],
#        [ 7.33539462],
#        [10.12590381],
#        [11.42356751],
#        [ 4.77911095],
#        [13.11265461],
#        [10.80021849],
#        [11.37378523],
#        [ 7.95417918],
#        [ 4.67963874],
#        [11.17116906],
#        [12.98656894],
#        [ 7.52021898],
#        [ 8.32223903],
#        [ 8.95069981],
#        [10.21202783],
#        [ 8.57809836],
#        [11.54668603],
#        [11.51067522],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_lr)
# Out:
# 0.5300147524184928

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
y_test
# Out:
# array([[13],
#        [ 8],
#        [11],
#        [ 5],
#        [12],
#        [11],
#        [ 7],
#        [ 8],
#        [ 7],
#        [ 9],
#        [ 8],
#        [ 8],
#        [11],
#        [ 9],
#        [ 4],
#        [ 7],
#        [ 7],
#        [17],
#        [ 7],
#        [ 7],
#        [ 7],
#        [ 5],
#        [ 8],
#        [ 9],
#        [10],
#        [10],
#        [ 5],
#        [15],
#        [10],
#        [14],
#        [ 8],
#        [ 4],
#        [ 9],
#        [13],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 9],
#        [ 8],
#        [11],
#        [15],
#        [12],
#        [17],
#        [16],
#        [11],
#        [11],
#        [ 8],
#        [10],
#        [11],
#        [ 6],
#        [13],
#        [ 7],
#        [13],
#        [20],
#        [12],
#        [ 7],
#        [ 8],
#        [10],
#        [ 7],
#        [ 7],
#        [ 9],
#        [ 9],
#        [11],
#        [ 8],
#        [ 7],
#        [12],
# ...

# %%
y_pred_dtr=dtr.predict(x_test)
y_pred_dtr
# Out:
# array([10., 11.,  9.,  5., 14.,  9.,  8.,  9.,  7., 12.,  9.,  6.,  8.,
#         7.,  6.,  8., 10., 15., 13.,  8.,  7.,  6., 10.,  8., 17., 11.,
#         4., 17., 13., 14.,  9.,  4.,  9., 14.,  6.,  9.,  9.,  9.,  8.,
#        20.,  8., 11., 16., 17., 13., 11.,  8., 13., 19., 10.,  9.,  6.,
#         7., 21.,  8.,  8.,  5.,  7.,  6.,  6., 10.,  9., 10.,  8.,  8.,
#        11., 12., 11., 10., 11.,  8., 14., 11.,  9.,  9.,  9., 11.,  8.,
#        18., 10.,  9.,  6.,  7., 12.,  9.,  8.,  9., 15.,  4.,  4.,  9.,
#         9.,  6.,  6., 13.,  7.,  9.,  8., 13., 12.,  9., 10., 12.,  9.,
#         5., 11.,  7.,  6.,  6., 14., 14., 13., 10.,  9., 16.,  9., 14.,
#        13.,  7., 11.,  7., 10.,  6.,  9., 11., 10.,  9., 10.,  7., 10.,
#        14.,  7., 11., 11.,  9., 10.,  9.,  8., 12., 10., 15., 12.,  6.,
#        10., 11.,  9., 10.,  7.,  9.,  6.,  8., 15.,  7., 11.,  9.,  6.,
#        10.,  7., 17., 10., 10.,  6., 10., 10.,  5., 13.,  5.,  5.,  9.,
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
acc_dtr=accuracy_score(y_test,y_pred_dtr)

# %%
acc_dtr
# Out:
# 0.2117224880382775

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_dtr))
# Out:
#               precision    recall  f1-score   support
#
#          3.0       1.00      0.40      0.57         5
#          4.0       0.41      0.64      0.50        11
#          5.0       0.45      0.30      0.36        33
#          6.0       0.26      0.36      0.30        47
#          7.0       0.32      0.26      0.28        98
#          8.0       0.28      0.28      0.28       113
#          9.0       0.23      0.26      0.25       127
#         10.0       0.21      0.23      0.22       107
#         11.0       0.14      0.13      0.13        95
#         12.0       0.11      0.09      0.10        66
#         13.0       0.11      0.10      0.11        39
#         14.0       0.04      0.04      0.04        26
#         15.0       0.11      0.11      0.11        18
#         16.0       0.00      0.00      0.00        14
#         17.0       0.08      0.10      0.09        10
#         18.0       0.00      0.00      0.00         5
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_train
# Out:
# <ipython-input-86-a8d6595261be>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(x_train,y_train)
# array([[ 5],
#        [ 3],
#        [15],
#        ...,
#        [10],
#        [ 9],
#        [ 8]], dtype=int64)

# %%
y_pred_rfr=rfr.predict(x_test)
y_pred_rfr
# Out:
# array([14.7 , 10.38, 10.67,  4.76, 11.12, 11.42,  7.85,  8.23,  8.31,
#        11.85,  8.31,  5.55,  9.06,  8.76,  5.87,  8.71,  8.91, 14.63,
#        11.34,  7.75,  7.42,  6.26,  9.12,  7.58, 11.79, 12.66,  4.08,
#        14.37, 10.06, 13.75,  9.3 ,  4.02, 11.71, 12.99,  6.57,  8.4 ,
#         8.56,  9.05,  8.03, 11.13, 11.63, 10.26, 14.08, 13.38, 12.04,
#         9.9 ,  8.8 , 12.71, 14.23,  7.99, 13.21,  6.42,  8.94, 14.45,
#         9.07,  7.91,  5.45,  8.52,  6.41,  6.81,  9.38,  8.88,  9.95,
#         6.97,  7.37, 11.72, 11.26, 12.15,  8.99, 14.59,  8.85, 15.91,
#        10.61, 10.  , 10.71,  9.15, 10.98,  9.93, 10.95,  8.17, 10.18,
#         5.57,  6.98, 12.73, 10.03,  7.88,  9.58, 12.18,  4.11,  6.64,
#         9.4 , 10.18,  7.48,  6.44, 13.78,  6.11, 10.29,  9.16, 14.37,
#        11.08,  9.41, 13.43, 10.22, 10.62,  5.09, 10.28,  7.91,  6.99,
#         8.38, 13.64, 10.31, 11.46, 11.73,  9.05, 15.66, 10.64, 11.14,
# ...

# %%
acc_rfr=r2_score(y_test,y_pred_rfr)

# %%
acc_rfr
# Out:
# 0.5712178624410229

# %%
from sklearn.svm import SVR
svm=SVR()
svm.fit(x_train,y_train)
# Out:
# C:\Users\umesh\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %%
y_pred_svr=svm.predict(x_test)

# %%
y_pred_svr
# Out:
# array([13.67735398,  9.07341941,  9.96838062,  4.43737987, 10.3332262 ,
#        10.76883742,  7.91673984,  9.35808634,  8.00847518, 11.35382617,
#         7.85494482,  5.78336571,  8.83281397,  8.97381013,  4.62871753,
#         9.22036243,  8.19173898, 13.2094357 , 10.43086606,  7.27677038,
#         7.25528532,  6.50186425,  8.48544957,  8.07064315, 10.02582065,
#        11.01260709,  4.73059256, 12.35137178,  9.93282032, 11.79744696,
#         8.42843918,  4.04185409, 10.98624216, 11.84950671,  6.79627473,
#         8.18905912,  8.32562984,  9.33939237,  7.93679906, 10.62542995,
#        11.07791151,  9.8118849 , 11.56762843, 11.48662373, 11.24990164,
#         9.45182829,  8.54164563, 11.10326238, 12.27558295,  7.54176877,
#        11.02566437,  6.86066667,  9.47367478, 12.54019588,  9.16650479,
#         8.08865699,  6.1720001 ,  7.91863644,  6.9081969 ,  6.76343047,
#         9.22582877,  8.46480723,  9.80392064,  7.16489767,  7.58264347,
# ...

# %%
acc_svr=r2_score(y_test,y_pred_svr)

# %%
acc_svr
# Out:
# 0.5559957143349785

# %%
import pickle
pickle.dump(rfr,open('age.pkl','wb'))
